# %%
import deposito_watcher.fusao_variaveis as fus
import pandas as pd
from bson.objectid import ObjectId

# %%
dict_query = { "$and": [{"id_experimento": ObjectId("5f8f5503d3d64947e0da22e0")}, 
                        {"var_ind.sexo":"macho"},
                        {"var_ind.analise":"primeira"}, # garantindo que esta pegando uma etografia por animal
                        {"$or": [{"var_ind.dosagem": "flx2.5mg"},
                                 {"var_ind.dosagem": "veiculo"}
                        ]}]}

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# c:\users\zn_jo\anaconda3\envs\py_d\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
fs = fus.Fusao_variaveis(dict_query)

# %%
# fs.set_variaveis_rastreamento(["@Vd", "@Van"])
# fs.set_variaveis_etografia(["nome"])
# list_des_etografia =["nome"]
# fs.set_variaveis_etografia(list_des_etografia)



lis_de_juncao = ["sexo", "dosagem", "unidade"]
fs.set_variaveis_juncao(lis_de_juncao)


li_str_descritores = ["duracao", "duracao_total", "path_experimento"]
li_str_categora = ["Immobility"]
fs.set_variaveis_descritore_eto_experimento(li_str_descritores, li_str_categora)

# %%
df = fs.get_dados_fundidos()
df
# Out:
#     d_e_Immobility_s  d_total_experimento  \
# 0   31.466667         297.500000
# 1   34.566667         247.800000
# 2   119.900000        246.666667
# 3   64.633333         245.700000
# 4   87.966667         247.500000
# 5   79.466667         247.700000
# 6   54.900000         269.033333
# 7   128.533333        247.666667
# 8   87.866667         247.333333
# 9   58.066667         247.533333
# 10  109.000000        245.633333
# 11  75.400000         248.533333
#
#                                                      path_experimento  \
# 0   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/1e4hb4.vxml
# 1   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2e3hc5.vxml
# 2   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3eh3d23.vxml
# 3   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/4e6hf2.vxml
# 4   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/5eh7g8.vxml
# 5   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/6e5h4h6.vxml
# 6   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2oh6b8.vxml
# 7   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/8o6hc5.vxml
# 8   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/1oh5d5.vxml
# 9   C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3o8hf5.vxml
# 10  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3oh8g9.vxml
# 11  C:/Mestrado Oficial Marino/Videos cegados/Calibrados/5oh7h6.vxml
#
#                       id_eto                      id_j   sexo   dosagem  \
# 0   5f8f5507d3d64947e0da2327  5f8f5507d3d64947e0da2323  macho  flx2.5mg
# 1   5f8f5508d3d64947e0da232f  5f8f5508d3d64947e0da232b  macho  flx2.5mg
# 2   5f8f550ad3d64947e0da234f  5f8f550ad3d64947e0da234b  macho  flx2.5mg
# 3   5f8f550bd3d64947e0da2357  5f8f550bd3d64947e0da2353  macho  flx2.5mg
# 4   5f8f550bd3d64947e0da235f  5f8f550bd3d64947e0da235b  macho  flx2.5mg
# 5   5f8f550cd3d64947e0da2367  5f8f550cd3d64947e0da2363  macho  flx2.5mg
# 6   5f8f5511d3d64947e0da23c7  5f8f5511d3d64947e0da23c3  macho  veiculo
# 7   5f8f5512d3d64947e0da23cf  5f8f5512d3d64947e0da23cb  macho  veiculo
# 8   5f8f5512d3d64947e0da23d7  5f8f5512d3d64947e0da23d3  macho  veiculo
# 9   5f8f5513d3d64947e0da23df  5f8f5513d3d64947e0da23db  macho  veiculo
# 10  5f8f5513d3d64947e0da23e7  5f8f5513d3d64947e0da23e3  macho  veiculo
# 11  5f8f5514d3d64947e0da23ef  5f8f5514d3d64947e0da23eb  macho  veiculo
#
#    unidade
# 0   A1
# 1   A2
# 2   A3
# 3   A4
# 4   A5
# 5   A6
# 6   A1
# 7   A2
# 8   A3
# 9   A4
# 10  A5
# 11  A6

# %%
df.loc[1:4]["path_experimento"]
# "Feita do mesmo arquivo de vídeo calibrado"


# Nenhum video foi feito a etografia usando esse xml
# db.getCollection('Etografia').find({"analiseEtografica.dadosVideoAnalisado.nomeVxml": "C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2e3hc5bis4.vxml"})
# Out:
# 1    C:/Mestrado Oficial Marino/Videos cegados/Calibrados/2e3hc5.vxml
# 2    C:/Mestrado Oficial Marino/Videos cegados/Calibrados/3eh3d23.vxml
# 3    C:/Mestrado Oficial Marino/Videos cegados/Calibrados/4e6hf2.vxml
# 4    C:/Mestrado Oficial Marino/Videos cegados/Calibrados/5eh7g8.vxml
# Name: path_experimento, dtype: object

# %%
# df = df.drop([2, 3, 4])
# df

# %%
# df = df.drop([9, 10, 11])
# df

# %%
df.to_csv('Dados_duracao_macho_1.csv', index=False)
